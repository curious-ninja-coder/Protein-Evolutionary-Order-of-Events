# %%
#now i have applied the viterbi algorithm of HMM(Hidden Markov Model) to predict the protein secondary struvture of a given amino acid sequence
import numpy as np

def viterbi4(in_prob, tr, em, obs_unknown, obsv_state, hidn_state):
    
    len_h = len(hidn_state)
    len_o = len(obsv_state)
    len_od = len(obs_unknown)
    
    # Convert inputs to numpy arrays
    tr = np.array(tr)
    em = np.array(em)
    in_prob = np.array(in_prob)
    
    # Initialize variables
    delta = np.zeros((len_h, len_od))
    shi = np.zeros((len_h, len_od), dtype=int)
    max_input1 = []
    solved_state = np.zeros(len_od, dtype=int)
    final_soln = []
    
    # Initialization for the first state
    f1 = obsv_state.index(obs_unknown[0])  # Find the index of the first observed state
    for i in range(len_h):
        delta[i, 0] = in_prob[i] * em[i, f1]
        shi[i, 0] = 0

    # Recursion for the rest of the states
    for j in range(len_od - 1):
        f = obsv_state.index(obs_unknown[j + 1])  # Find index of the next observed state
        for k in range(len_h):
            weighted_input = delta[:, j] * tr[:, k]
            max_input = np.max(weighted_input)
            max_idx = np.argmax(weighted_input)
            shi[k, j + 1] = max_idx
            delta[k, j + 1] = max_input * em[k, f]
        max_input1.append(np.max(delta[:, j + 1]))

    # Backtracking to find the most likely sequence of hidden states
    solved_state[-1] = np.argmax(delta[:, -1])
    for jj in range(1, len_od):
        solved_state[-jj - 1] = shi[solved_state[-jj], len_od - jj]

    # Convert solved_state indices to the hidden state sequence
    for idx in solved_state:
        final_soln.append(hidn_state[idx])

    return final_soln
# starting of inputs
in_prob = [0.09, 0.03, 0.03, 0.03, 0.03, 0.1, 0.01, 0.04, 0.03, 0.04, 0.14, 0.03, 0.03, 0.0, 0.07, 0.07, 0.11, 0.09, 0.01, 0.01]  # Initial probabilities for hidden states
 # Transition probabilities
tr =[[0.11, 0.03, 0.05, 0.07, 0.03, 0.06, 0.02, 0.07, 0.06, 0.08, 0.03, 0.04, 0.04, 0.03, 0.03, 0.07, 0.06, 0.06, 0.03, 0.03], [0.09, 0.03, 0.04, 0.02, 0.04, 0.08, 0.03, 0.05, 0.05, 0.05, 0.0, 0.07, 0.06, 0.04, 0.05, 0.08, 0.07, 0.08, 0.0, 0.07], [0.09, 0.02, 0.04, 0.07, 0.04, 0.08, 0.02, 0.06, 0.07, 0.08, 0.02, 0.03, 0.03, 0.03, 0.03, 0.06, 0.06, 0.08, 0.03, 0.05], [0.1, 0.01, 0.04, 0.06, 0.05, 0.09, 0.02, 0.05, 0.1, 0.09, 0.02, 0.05, 0.04, 0.04, 0.04, 0.04, 0.04, 0.06, 0.02, 0.04], [0.08, 0.02, 0.08, 0.06, 0.04, 0.07, 0.02, 0.08, 0.06, 0.05, 0.02, 0.07, 0.03, 0.03, 0.05, 0.06, 0.09, 0.06, 0.0, 0.02], [0.07, 0.01, 0.07, 0.06, 0.03, 0.07, 0.03, 0.06, 0.07, 0.06, 0.03, 0.06, 0.03, 0.03, 0.04, 0.07, 0.08, 0.06, 0.02, 0.05], [0.11, 0.01, 0.04, 0.05, 0.04, 0.06, 0.01, 0.08, 0.05, 0.07, 0.02, 0.04, 0.07, 0.03, 0.05, 0.06, 0.07, 0.04, 0.04, 0.05], [0.1, 0.01, 0.07, 0.06, 0.03, 0.08, 0.03, 0.05, 0.06, 0.06, 0.01, 0.06, 0.05, 0.03, 
HHHHHHHHHHHUHHHHHHHHHHHHHHHTUTTUUUUUHHHHHHHHHHHHTUGGGUUUHHHHHHHHHHHHTUUHHHHHHHHHHHUGGGUUTTHHHHHHHHHHHHHHHHHHSUUHHHHHHHHHHHHTTUUHHHHHHHHHHHHHHHHHTUUUUHHHHHHHHHHHHHHHHHTTUTHHHHHHHHHHTU', 'UEEEEEEEEEUSSUSHHHHHHHHHHHHHHHHHHHTUUGGGEEEEEEEEUTTUUSSUGGGGGGGSTTUTTSUEEEEEUUUUTTUUSSEEEEEEEEEUUSUGGGUUUEEUGGGGGTUTTUU', 'UEEEEEEESSUBUSEEEEEEEEUUUUTTEEEEEEEEEUTTSSSUUEEEEEEEETTUTTEEEEEEEBTTBUUUUEEEEUSSUGGGSUEEEEEEEETTEEEEEETTEEEEEEUSSUUUSUBEEEEEEEEBSSUHHHHUUUUUUUUEEEEEEEEEEEETTEEEEEUUSSUUTTTEEEUUSBUUUTTBUSEEUGGGEEEUTTSUEEEEEBUU', 'HHHHHHHHHUUUEEEEEETTSUEEEEUTTUUUUUHHHHHHHHHHHHSTTSSTTTUEEETTEEEEEEEEETTTEEEEEETTEEEEEEEUSSEEEEEEEUTTSUHHHHHHHHHHHHHHHHHTTU', 'EEUSSHHHHHHHHHHHTTTUUHHHHHHHHSUEEUSSSUUUGGGUU', 'BUGGGTTSBHHHHHHHHHHHUTTSEEEEEETTUUEEUUUUTTEEEEEEETTTTEEUSUUEEU', 'UUTTSHHHHTUHHHHHHHHHHHHHHHHHHHHHHTTSUUUHHHHSTTUGGGUUTTUUSUHHHHHHHHHHHHHHHTTGGGSTTUUUSUTTTUUUUSSUUUUUUUUSUTTGGGUUUHHHHHHHHHHTTHHHHSSSSSUUTTUHHHHHHHHHHHHHHHHHHHHTHHHHHHHHHHHTHHHHHHHHHTTUHHHHHHHHUUHHHHHHHHHHHHHHHHHTTSUUUUUSSUHHHHHHHHHHTHHHHHHHHHHHHHHTGGGU', 'UEEEEEEEUGGGHHHHHHHHHHHHUUUHHHHHHHHHTUSEEEEEEEUHHHHHHHHHHHHHHTUEEEEU', 'UGGGTSUEETTEEUUSUTTUTTSSUBUUTTUUSTTBHHHHHHUSSUSSUUHHHHHHHHHTTUHHHHHHHHUSSSSSSUU']

# Observed sequence
obsv_state = "SHTUEGB"  # Possible observed states
hidn_state = 'ACDEFGHIKLMNPQRSTVWY'  # Possible hidden states"SHTUEGB"

# Run the Viterbi algorithm
predicted_sequence_list=[]
for obs_unknown in testing_structure_list:
    predicted_sequence=viterbi4(in_prob, tr, em, obs_unknown, obsv_state, hidn_state)
    predicted_sequence = "".join(predicted_sequence)
    predicted_sequence_list.append(predicted_sequence)
print(predicted_sequence_list)
# Out:
# ['', 'MPGTGTGSGSVVVVTGGGTVVVVVTGGGTGSVVVVVVVVTGSGGNPVVVVVVVTGGTGTDLSGTVVVVVVVVTGTGNPGGTGSVVVVVVVTGGNPVVVVVVTGGGNPVVVVVVTGGTGNPAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAALASGNLAAAAAAAAAAAAAAAAAGSGNLAAAAAAAAAAAAAAAAAAAAAA', 'MPGGDLLNLAAAAAAAAAAAAAAGGSGSGAAAAAAAAAAAAALNPGGGGAAAASGTGGGNPGAAAAAAAAAAAAAAGGTGNPLNP', '...', '
# ...
