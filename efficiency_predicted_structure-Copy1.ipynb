', 'UHHHHHHHHHHHHHHHHHHHHHHHHHSUU', 'UUSHHHHHHHHHHHHHHHHHHHHHHHUHHHHHHHHHHHHHHHTUTTUUUUUHHHHHHHHHHHHTUGGGUUUHHHHHHHHHHHHTUUHHHHHHHHHHHUGGGUUTTHHHHHHHHHHHHHHHHHHSUUHHHHHHHHHHHHTTUUHHHHHHHHHHHHHHHHHTUUUUHHHHHHHHHHHHHHHHHTTUTHHHHHHHHHHTU', 'UEEEEEEEEEUSSUSHHHHHHHHHHHHHHHHHHHTUUGGGEEEEEEEEUTTUUSSUGGGGGGGSTTUTTSUEEEEEUUUUTTUUSSEEEEEEEEEUUSUGGGUUUEEUGGGGGTUTTUU', 'UEEEEEEESSUBUSEEEEEEEEUUUUTTEEEEEEEEEUTTSSSUUEEEEEEEETTUTTEEEEEEEBTTBUUUUEEEEUSSUGGGSUEEEEEEEETTEEEEEETTEEEEEEUSSUUUSUBEEEEEEEEBSSUHHHHUUUUUUUUEEEEEEEEEEEETTEEEEEUUSSUUTTTEEEUUSBUUUTTBUSEEUGGGEEEUTTSUEEEEEBUU', 'HHHHHHHHHUUUEEEEEETTSUEEEEUTTUUUUUHHHHHHHHHHHHSTTSSTTTUEEETTEEEEEEEEETTTEEEEEETTEEEEEEEUSSEEEEEEEUTTSUHHHHHHHHHHHHHHHHHTTU', 'EEUSSHHHHHHHHHHHTTTUUHHHHHHHHSUEEUSSSUUUGGGUU', 'BUGGGTTSBHHHHHHHHHHHUTTSEEEEEETTUUEEUUUUTTEEEEEEETTTTEEUSUUEEU', 'UUTTSHHHHTUHHHHHHHHHHHHHHHHHHHHHHTTSUUUHHHHSTTUGGGUUTTUUSUHHHHHHHHHHHHHHHTTGGGSTTUUUSUTTTUUUUSSUUUUUUUUSUTTGGGUUUHHHHHHHHHHTTHHHHSSSSSUUTTUHHHHHHHHHHHHHHHHHHHHTHHHHHHHHHHHTHHHHHHHHHTTUHHHHHHHHUUHHHHHHHHHHHHHHHHHTTSUUUUUSSUHHHHHHHHHHTHHHHHHHHHHHHHHTGGGU', 'UEEEEEEEUGGGHHHHHHHHHHHHUUUHHHHHHHHHTUSEEEEEEEUHHHHHHHHHHHHHHTUEEEEU', 'UGGGTSUEETTEEUUSUTTUTTSSUBUUTTUUSTTBHHHHHHUSSUSSUUHHHHHHHHHTTUHHHHHHHHUSSSSSSUU']
print(len(predicted_structure_list),len(testing_structure_list))
accuracy_list=[]
for i in range(len(testing_structure_list)):
    match=0
    for j in range(len(testing_structure_list[i])):
        if testing_structure_list[i][j]==predicted_structure_list[i][j]:
            match+=1
    match=(match/len(testing_structure_list[i]))*100
    match=round(match,2)
    accuracy_list.append(match)
print(accuracy_list)
accuracy_percentage=round((((sum(i for i in accuracy_list))/(100*(len(accuracy_list))))*100),2)
print(accuracy_percentage)
# Out:
# 21 21
# [39.27, 39.07, 54.12, 9.24, 32.51, 39.35, 14.1, 0.98, 42.26, 47.5, 30.04, 86.21, 74.62, 16.81, 2.4, 31.15, 6.67, 30.65, 57.14, 51.47, 30.38]
# 35.04
